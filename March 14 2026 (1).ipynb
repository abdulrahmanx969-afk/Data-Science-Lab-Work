# %%
### Titanic Data
### Predict wheather the person is survived or not?
### classification based problem
### LR, DT, KNN
### Data Proccessing : Missing Data has to be imputed
### Standardscalar

# %%
### Data Analysation:
import numpy as np
import pandas as pd

### Visualization:
import matplotlib.pyplot as plt
import seaborn as sns

#### StandardScaler
from sklearn.preprocessing import StandardScaler

#### KNN
from sklearn.neighbors import KNeighborsClassifier

### Performance metric
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, classification_report

# %%
### Load the data
df_train = pd.read_csv("/content/Titanic Dataset.csv")
df_test = pd.read_csv("/content/Titanic Dataset.csv")

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
 100 * (df_train.isnull().sum()) / len(df_train)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df_train["Age"].median()
# Out:
# 28.0

# %%
df_train["Fare"].median()
# Out:
# 14.4542

# %%
df_train[df_train["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df_train[df_train["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df_train["Age"] = df_train["Age"].fillna(df_train["Age"].median())

df_train = df_train.drop(["Cabin"], axis = 1)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
df_train["Survived"] = df_train["Survived"].apply(str)
df_train["Pclass"]   = df_train["Pclass"].apply(str)

df_test["Survived"] = df_test["Survived"].apply(str)
df_test["Pclass"]   = df_test["Pclass"].apply(str)

# %%
df_train_num = df_train.select_dtypes(exclude = "object")
df_train_obj = df_train.select_dtypes(include = "object")

# %%
#### for different values of k we are going to check
Performance_Metric = []

for k in range(1,30):
    knn_k = KNeighborsClassifier(n_neighbors=k)
    knn_k.fit(scaled_X_train, y_train)
    y_pred_k = knn_k.predict(scaled_X_test)
    accuracy_k = accuracy_score(y_test, y_pred_k)
    Performance_Metric.append(accuracy_k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1150/2651483176.py in <cell line: 0>()
#       4 for k in range(1,30):
#       5     knn_k = KNeighborsClassifier(n_neighbors=k)
# ----> 6     knn_k.fit(scaled_X_train, y_train)
#       7     y_pred_k = knn_k.predict(scaled_X_test)
#       8     accuracy_k = accuracy_score(y_test, y_pred_k)
#
# NameError: name 'scaled_X_train' is not defined
